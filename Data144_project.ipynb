# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv("/content/drive/My Drive/DMA project/data/weather_data.csv")

# %%
#create column "Wildfire_Occurred"(set as below criteria) 0 or 1
data["Wildfire_Occurred"] = data["Wildfire_Occurred"] = (
    (data["Precipitation_mm"] <= 5) &
    (data["Wind_Speed_kmh"] >= 15)
).astype(int)
data['Month'] = pd.to_datetime(data["Date_Time"]).dt.month    # add this for predict wildfire risk location and month

# %%
data
# Out:
#             Location            Date_Time  Temperature_C  Humidity_pct  \
# 0          San Diego  2024-01-14 21:12:46      10.683001     41.195754
# 1          San Diego  2024-05-17 15:22:10       8.734140     58.319107
# 2          San Diego  2024-05-11 09:30:59      11.632436     38.820175
# 3       Philadelphia  2024-02-26 17:32:39      -8.628976     54.074474
# 4        San Antonio  2024-04-29 13:23:51      39.808213     72.899908
# ...              ...                  ...            ...           ...
# 999995        Dallas  2024-01-01 20:29:48      23.416877     37.705024
# 999996   San Antonio  2024-01-20 15:59:48       6.759080     40.731036
# 999997      New York  2024-04-14 08:30:09      15.664465     62.201884
# 999998       Chicago  2024-05-12 20:10:43      18.999994     63.703245
# 999999      New York  2024-04-16 16:11:52      10.725351     43.804584
#
#         Precipitation_mm  Wind_Speed_kmh  Wildfire_Occurred  Month
# ...

# %%
#set x(features) and y(target)
x = data.drop(columns=["Wildfire_Occurred", "Date_Time", "Location"])
y = data["Wildfire_Occurred"]

# %%
#split train test set
X_train, X_val, y_train, y_val = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
#ML Random Forest
rf_model = RandomForestClassifier(
    n_estimators=100,
    max_depth=10,
    min_samples_split=10,
    random_state=42
)
rf_model.fit(X_train, y_train)
rf_predict = rf_model.predict(X_val)

# %%
#Accuracy
accuracy = accuracy_score(y_val, rf_predict)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 1.00

# %%
#predict with value on data
first_predict = pd.DataFrame(
    [[38.304456, 32.298644, 2.570483, 22.996614	, 4]],
    columns = x.columns
)
first_prediction = rf_model.predict(first_predict)
print(f"Predicted Class: {first_prediction}")
# Out:
# Predicted Class: [1]

# %%
data2 = pd.read_csv("/content/drive/My Drive/DMA project/data/usa_rain_prediction_dataset_2024_2025.csv")
data2['Month'] = pd.to_datetime(data2["Date"]).dt.month
data2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bc97ece89846> in <cell line: 1>()
# ----> 1 data2 = pd.read_csv("/content/drive/My Drive/DMA project/data/usa_rain_prediction_dataset_2024_2025.csv")
#       2 data2['Month'] = pd.to_datetime(data2["Date"]).dt.month
#       3 data2
#
# NameError: name 'pd' is not defined

# %%
filtered_data = data2.groupby(['Location', 'Month']).head(1).reset_index(drop=True)
filtered_data
# Out:
#            Date         Location  Temperature   Humidity  Wind Speed  \
# 0    2024-01-01         New York    87.524795  75.655455   28.379506
# 1    2024-02-01         New York    40.852962  72.743139    5.520706
# 2    2024-03-01         New York    32.395646  70.835873   24.800697
# 3    2024-04-01         New York    39.597487  35.957132    5.950242
# 4    2024-05-01         New York    45.684726  84.777132    5.321728
# ..          ...              ...          ...        ...         ...
# 235  2024-08-01  Washington D.C.    84.399054  29.600873   18.657580
# 236  2024-09-01  Washington D.C.    68.734925  33.998815    8.473870
# 237  2024-10-01  Washington D.C.    93.945262  59.107452   22.794776
# 238  2024-11-01  Washington D.C.    31.898224  93.681493   26.878549
# 239  2024-12-01  Washington D.C.    59.220306  25.805750    4.168257
#
#      Precipitation  Cloud Cover     Pressure  Rain Tomorrow  Month
# 0         0.000000    69.617966  1026.030278              0      1
# ...
